# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Created on Wed Feb 8 14:44:33 2023
Based on: https://www.kaggle.com/datasets/arbazmohammad/world-airports-and-airlines-datasets
Sample input: --AIRLINES="airlines.yaml" --AIRPORTS="airports.yaml" --ROUTES="routes.yaml" --QUESTION="q1" --GRAPH_TYPE="bar"
@author: rivera
@author: STUDENT_ID
"""
import yaml






#def sample_function(input: str) -> str:
#    """Sample function (removable) that illustrations good use of documentation.
#            Parameters
#            ----------
#                input : str, required
#                    The input message.
#
#
 #           Returns
#            -------
#                str
#                    The text returned.
#    """
#    return input.upper()


import pandas as pd

def main():
    with open('airlines.yaml', 'r') as f:
   
        airlines_data = yaml.safe_load(f)
        airlines_df = pd.DataFrame(airlines_data)
        print(airlines_df)
    
      
       
    with open('airports.yaml', 'r') as f:
        airports_data = yaml.safe_load(f)
        airports_df = pd.DataFrame(airports_data)

    with open('routes.yaml', 'r') as f:
        routes_data = yaml.safe_load(f)
        routes_df = pd.DataFrame(routes_data)
        
   # Check if airport_id is present in airports and routes data frames
    if 'airport_id:' not in airports_df.columns:
        raise ValueError('airport_id column is missing in airports data frame')
    if 'route_from_aiport_id' not in routes_df.columns:
        raise ValueError('route_from_aiport_id column is missing in routes data frame')
    if 'route_to_airport_id' not in routes_df.columns:
        raise ValueError('route_to_airport_id column is missing in routes data frame')

    # Merge the data frames
    #merged_df = pd.merge(routes_df, airports_df, left_on='route_from_aiport_id', right_on='airport_id', how='left')
    #merged_df = pd.merge(merged_df, airports_df, left_on='route_to_airport_id', right_on='airport_id', how='left', suffixes=('_from', '_to'))
    #merged_df = pd.merge(merged_df, airlines_df, left_on='route_airline_id', right_on='airline_id', how='left')

    # Drop the unnecessary columns
    #merged_df = merged_df.drop(['airport_id_from', 'airport_id_to', 'airline_id'], axis=1)

    # Print the final data frame
    #print(merged_df)


    
    # Merge airlines_df and airports_df on the 'country' column
    #airlines_airports_df = pd.merge(airlines_df, airports_df, on='airline_name')
    # Merge airlines_airports_df and routes_df on the 'airline' column
    #merged_df = pd.merge(airlines_airports_df, routes_df, on='airline')
    #print(merged_df)
    
    
    
   
        
    
    


      
        
    #"""Main entry point of the program."""
    # calling the sample function
    #print(sample_function(input="your code should be here."))


if __name__ == '__main__':
    main()
# Out:
#                                                airlines
# 0     {'airline_id': '2', 'airline_name': '135 Airwa...
# 1     {'airline_id': '3', 'airline_name': '1Time Air...
# 2     {'airline_id': '4', 'airline_name': '2 Sqn No ...
# 3     {'airline_id': '5', 'airline_name': '213 Fligh...
# 4     {'airline_id': '6', 'airline_name': '223 Fligh...
# ...                                                 ...
# 6042  {'airline_id': '19828', 'airline_name': 'Vuela...
# 6043  {'airline_id': '19830', 'airline_name': 'All A...
# 6044  {'airline_id': '19831', 'airline_name': 'Fly E...
# 6045  {'airline_id': '19834', 'airline_name': 'FlyPo...
# 6046  {'airline_id': '19845', 'airline_name': 'FTI F...
#
# [6047 rows x 1 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/01/2yvtxtrj6fgf56ngvy06bjpw0000gn/T/ipykernel_3320/2160914621.py in <module>
#      93
# ...
